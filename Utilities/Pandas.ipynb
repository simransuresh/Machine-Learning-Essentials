# %% [markdown]
# # contents
# 1. file upload
# 2. read csv
# 3. read column, row using iloc, loc
# 4. column refers to axis=1 and row refers to axis=0
# 5. sorting
# 6. adding and dropping columns

# %%
# IMPORTING CSV,XLSX,TXT FILES
from google.colab import files
uploaded = files.upload()
# type(uploaded)
# Out:
#      <input type="file" id="files-a47f7108-9016-479e-a9e2-27f47f60da6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a47f7108-9016-479e-a9e2-27f47f60da6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon_data.csv to pokemon_data.csv

# %%
# READING THE FILE
import io
import pandas as pd
df = pd.read_csv(io.BytesIO(uploaded['pokemon_data.csv']))
# df.shape
df.head(5)
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
# Read Headers
# df.columns

# Read each Column
# df[['Name', 'Type 1', 'HP']]
# df.shape

# # Read Each Row
# df.iloc[56:90]

# # Read a specific location (R,C)
# read_string = df.iloc[2,1]
# read_string

# for index, row in df.iterrows():
#     print(index, row['Name'])

# FILTERING
grass = df.loc[df['Type 1'] == "Grass"]
# NUMBER OF ENTRIES
len(grass)
# Out:
# 70

# %%
# df.describe

# SORTING ASC/DESC
new_df = df.head(10).sort_values(['HP', "Type 1"], ascending=[0, 1])

new_df
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 4  4                 Charmander   Fire  ...    65           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
#
# [10 rows x 12 columns]

# %%
# ADDING COLUMNS
# df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
# new_df = df.head(10)
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df

# top = new_df.sort_values(["Total"], ascending=False)
# top.iloc[0, -1]
# 45+49+49+65+65+45	

# DROPPING COLUMNS
# df = df.drop(columns=['Total'])
# df

# CONVERTING DATAFRAME COLUMNS INTO PYTHON LIST
cols = list(df.columns)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
# SAVING NEW CSV FILES
# df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

# df.to_csv('modified.txt', index=False, sep='\t')

# %%
# FILTERING AND SAVING NEW FILES
# new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# new_df

# new_df.reset_index(drop=True, inplace=True)
# new_df

# new_df.to_csv('filtered.csv')

# %%
# CONDITIONAL UPDATE
# df.loc[df['Total'] > 500, ['Generation','Legendary']] = ["abc", 0]

# df

# df["Type 1"][0]

# df = df.drop(columns=['Type'])
# df

df["mean"] = df.iloc[:,7:9].mean(axis=1)
df.loc[df["mean"][:] > 100, ['Generation','Legendary']] = ["xyz", "def"]
df
# df = pd.read_csv('modified.csv')

# df
# Out:
#        #                   Name   Type 1  ... Legendary  Total   mean
# 0      1              Bulbasaur    Grass  ...     False    318   65.0
# 1      2                Ivysaur    Grass  ...     False    405   80.0
# 2      3               Venusaur    Grass  ...         0    525  100.0
# 3      3  VenusaurMega Venusaur    Grass  ...       def    625  121.0
# 4      4             Charmander     Fire  ...     False    309   55.0
# ..   ...                    ...      ...  ...       ...    ...    ...
# 795  719                Diancie     Rock  ...       def    600  125.0
# 796  719    DiancieMega Diancie     Rock  ...       def    700  135.0
# 797  720    HoopaHoopa Confined  Psychic  ...       def    600  140.0
# 798  720     HoopaHoopa Unbound  Psychic  ...       def    680  150.0
# 799  721              Volcanion     Fire  ...       def    600  110.0
#
# [800 rows x 14 columns]

# %%
# GROUP BY OPERATIONS

# df = pd.read_csv('modified.csv')

# df['count'] = 1
# df
df.head(30).groupby(['Type 1', 'Type 2']).count()
# Out:
#                #  Name  HP  Attack  ...  Legendary  Total  mean  count
# Type 1 Type 2                       ...
# Bug    Flying  1     1   1       1  ...          1      1     1      1
#        Poison  4     4   4       4  ...          4      4     4      4
# Fire   Dragon  1     1   1       1  ...          1      1     1      1
#        Flying  2     2   2       2  ...          2      2     2      2
# Grass  Poison  4     4   4       4  ...          4      4     4      4
# Normal Flying  6     6   6       6  ...          6      6     6      6
#
# [6 rows x 13 columns]

# %%
# BIG DATA IN CHUNKS
# new_df = pd.DataFrame(columns=df.columns)
# new_df.shape

for df in pd.read_csv('pokemon_data.csv', chunksize=5):
    print(df)
    # results = df.groupby(['Type 1']).count()
    # new_df = pd.concat([new_df, results])
# new_df.head(12)
# Out:
#     #                       Name Type 1  ... Speed  Generation  Legendary
# 0   1                  Bulbasaur  Grass  ...    45           1      False
# 1   2                    Ivysaur  Grass  ...    60           1      False
# 2   3                   Venusaur  Grass  ...    80           1      False
# 3   3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4   4                 Charmander   Fire  ...    65           1      False
# 5   5                 Charmeleon   Fire  ...    80           1      False
# 6   6                  Charizard   Fire  ...   100           1      False
# 7   6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8   6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9   7                   Squirtle  Water  ...    43           1      False
# 10  8                  Wartortle  Water  ...    58           1      False
# 11  9                  Blastoise  Water  ...    78           1      False
#
# ...
