# %% [markdown]
# Data visualization library in Python
#
# Pyplot documentation at https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html
#
# Full documentation at https://matplotlib.org/stable/gallery/index.html#pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Basic line plot
x = [0,1,2,3,4]
y = [0,2000,4000,6000,8000]
# plt.plot(x, y)

plt.figure(figsize=(10,3), dpi=100)
# plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')
# Shorthand notation
# fmt = '[color][marker][line]'
# plt.plot(x,y, 'g^--', label='2x')

# Line 2
# select interval we want to plot points at
# x2 = np.arange(0,4.5,0.5)
# # Plot part of the graph as line
# plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')
# # Plot remainder of graph as a dot
# plt.plot(x2[5:], x2[5:]**2, 'r--')

# Add a title (specify font parameters with fontdict)
plt.title('Our First Graph!', fontdict={'fontname': 'Arial', 'fontsize': 20})

# X and Y labels
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# X, Y axis Tickmarks (scale of your graph)
plt.xticks([0,1,2,3,4,5])
plt.yticks([0,2,4,6,8,10])

# Add a legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolution)
plt.savefig('mygraph.png', dpi=300)


# Show plot
plt.show()
# Out:
# No handles with labels found to put in legend.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
# bar plot

labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(10,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
# for index, bar in enumerate(bars):
#   bar.set_hatch(patterns[index])
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.xticks(X_axis, X)
plt.xlabel("Years")
plt.ylabel("Dollars ($)")
plt.title("Number of Students in each group")
plt.legend()
plt.show()

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
# LINE GRAPH
# from google.colab import files
# import io

# uploaded = files.upload()

# gas = pd.read_csv(io.BytesIO(uploaded['gas_prices.csv']))

plt.figure(figsize=(8,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

# plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
# plt.plot(gas.Year, gas.Canada, 'r.-', label="Canada")
# plt.plot(gas.Year, gas['South Korea'], 'g.-', label="South Korea")
# plt.plot(gas.Year, gas.Australia, 'y.-', label="Australia")

# Another Way to plot many values!
countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
for country in gas:
    if country in countries_to_look_at:
        plt.plot(gas.Year, gas[country], marker='.', label=country)

plt.grid(which='major', axis='both')
plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %%
# HISTOGRAM
from google.colab import files
import io

upload = files.upload()
# Out:
#      <input type="file" id="files-57e4e869-0f42-4461-9edb-98a1f306999d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57e4e869-0f42-4461-9edb-98a1f306999d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fifa_data.csv to fifa_data (1).csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1426eb0a38b4> in <module>()
#       3 import io
#       4 upload = files.upload()
# ----> 5 fifa = pd.read_csv(io.BytesIO(uploaded['fifa_data.csv']))
#       6 fifa.head(5)
#       7
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

fifa = pd.read_csv(io.BytesIO(upload['fifa_data.csv']))
fifa.head(5)

bins = [40,50,60,70,80,90,100]

plt.figure(figsize=(8,5))

plt.hist(fifa.Overall, bins=bins, color='#abcdef')

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.savefig('histogram.png', dpi=300)

plt.show()

# %% [markdown]
# restaurant manager
# input [1Bread, 4Eggs, 2Lemon, ], [], [3B],
# constraints
# output [1, 2], [1x---], []
#
# Priority queue

# %%
# pie chart

left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(8,5))

labels = ['Left', 'Right']
colors = ['blue', 'green']

plt.pie([left, right], labels = labels, colors=colors, autopct='%.2f %%')

plt.title('Foot Preference of FIFA Players')

plt.show()
