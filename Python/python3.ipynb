# %%
if all([True if num %2 == 0 else False for num in range(1, 5, 2) ]):
  print("yes")

# %%
l1 = [1, 2, 3]
l1 = ''.join(str(e) for e in l1)
print(l1)
# Out:
# 123

# %%
l = "123"
# l1 = l.split()
l = list(l)
print(l)

print("".join(l))
# Out:
# ['1', '2', '3']
# 123

# %%
print("testing", end="1")
# Out:
# testing1

# %%
print("yes", "no", sep="-")
# Out:
# yes-no
