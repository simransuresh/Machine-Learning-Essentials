# %%
l = [1, 2, 3]

# %%
l.count(2)
# Out:
# 1

# %%
sum(l)
# Out:
# 6

# %%
# list comprehension
l = [number for number in range(5)]

# %%
l = [index if index % 2 == 0 else 0 for index in range(10)]

# %%
print(l)
# Out:
# [0, 0, 2, 0, 4, 0, 6, 0, 8, 0]

# %%
l[0] = 4

# %%
print(l)
# Out:
# [4, 0, 2, 0, 4, 0, 6, 0, 8, 0]

# %%
l2 = [[1, 2], [3, 4], [5, 6]]
l2 = [[index] for index in range(6)]

# %%
print(l2)
# Out:
# [[0], [1], [2], [3], [4], [5]]

# %%
d = {"1": "test", "2": "test2"}

# %%
d_items = d.items()
print(d_items)
# Out:
# dict_items([('1', 'test'), ('2', 'test2')])

# %%
d_comp = {key: value for key, value in d.items()}
print(d_comp)
# set_item
# Out:
# {'1': 'test', '2': 'test2'}

# %% [markdown]
# # New Section

# %%
d_comp = {key: value for key, value in d.items() if int(key) % 2 != 0}
print(d_comp)
# Out:
# {'1': 'test'}

# %%
l = [1, 2, 3]
d = {str(index):l[index] for index in range(len(l))}
print(d)
# Out:
# {'0': 1, '1': 2, '2': 3}

# %%
l.insert(0, 4)
print(l)
# Out:
# [4, 4, 1, 2, 3]

# %%
l.append(5)
print(l)
# Out:
# [4, 4, 1, 2, 3, 5, 5]

# %%
l.remove(4)
print(l)
# Out:
# [4, 1, 2, 3, 5, 5]

# %%
del l[0]
print(l)
# Out:
# [1, 2, 3, 5, 5]

# %%
del l
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-3db29c61a670> in <module>()
#       1 del l
# ----> 2 print(l)
#
# NameError: name 'l' is not defined

# %%
d = {}
d.__setitem__("message", "hello")

d.__setitem__("name", "test")
print(d)
d_comp.__setitem__("3", 3)

d_comp["4"] = 4
print(d_comp)
# Out:
# {'message': 'hello', 'name': 'test'}
# {'1': 'test', '3': 3, '4': 4}

# %%
d = {'0': 1, '1': 2, '2': 3}
d_list = [int(element) for element in d.keys()]
print(sum(d_list))
# Out:
# 3

# %%
# counting frequency of every character in string
l = "32452264577"
# output - {"3": 1, "2": 3, "4": 2, "5": 2, "6": 1, "7": 2}

# %%
with open("Desktop/test.json", "r") as fp:
# Out:
#   File "<ipython-input-41-78522fddc84c>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
json_data = [{
    "userId": 1,
    "id": 1,
    "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
    "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
  },
  {
    "userId": 2,
    "id": 2,
    "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
    "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
  }]

# %%
json_list = [val for index in json_data for key, val in index.items() if key == "userId"]
print(json_list)
# Out:
# [1, 2]

# %% [markdown]
# # class 2

# %%
l1 = [1, 2, 3]
l2 = [2, 3, 4]

print(list(set(l1+l2)))
print([num for num in l1 if num in l2])
# Out:
# [1, 2, 3, 4]
# [2, 3]

# %%
s = "-v-v-v-"
print(s.strip("-"))
# Out:
# v-v-v

# %%
def mod(num):
  return num if num % 2 == 0 else None

w = [1, 2, 3, 4, 5]
w = list(map(mod, w))
print(w)
# Out:
# [None, 2, None, 4, None]

# %%
# list of letters
letters = ['a', 'b', 'd', 'e', 'i', 'j', 'o']

# function that filters vowels
def filter_vowels(letter):
    vowels = ['a', 'e', 'i', 'o', 'u']

    return True if letter in vowels else False

filtered_vowels = filter(filter_vowels, letters)

print('The filtered vowels are:')
for vowel in filtered_vowels:
    print(vowel)
# Out:
# The filtered vowels are:
# a
# e
# i
# o

# %%
import functools
w = [1, 2, 3, 4, 5]
print(functools.reduce(lambda a,b : a+b,w))
# Out:
# 15

# %%
print("sSs".capitalize())
d = "simran"
print(d[0].upper() + d[1:])

w = [1, 2, 3, 4, 5]
w.sort(reverse=True)
print(w)
# Out:
# Sss
# Simran
# [5, 4, 3, 2, 1]

# %%
def binary_search(l, search):
  mid = int(l.len() / 2)
  if l[mid] == search:
    return mid
  elif l[mid] > search:
    return binary_search(l[0, mid], search)
  else:
    return binary_search(l[mid+1, l.len()], search)
