# %%
non linear multi class classification/linear binary classification

# %% [markdown]
# # k nearest neighbors
#
# k - number of nearest neighbors chosen
#
# ![image.png](data:image/png;base64,...)

# %%
algorithm:
1. choose k as the number of neighbors
2. calculate the distance between the new dataset and k nearest neighbors of it

# %% [markdown]
# p = 1 , Manhattan Distance
# p = 2 , Euclidean Distance
# p = infinity , Cheybchev Distance

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files
import io

upl = files.upload()
# Importing the dataset
dataset = pd.read_csv(io.BytesIO(upl['Social_Network_Ads.csv']))
# Out:
#      <input type="file" id="files-7ff5e57d-6919-4940-b159-81496f4f23ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ff5e57d-6919-4940-b159-81496f4f23ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Social_Network_Ads.csv to Social_Network_Ads (3).csv

# %%
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, -1].values

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# we fit the training data set so we use fit_transform
# self.fit().transform()
X_train = sc.fit_transform(X_train)
# we dont fit the test data just use 
# self.transform()
X_test = sc.transform(X_test)

# Training the K-NN model on the Training set
from sklearn.neighbors import KNeighborsClassifier
# minkowski is same as Euclidean distance
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'manhattan', p = 1)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
ac = accuracy_score(y_test, y_pred)

print(cm)
print(ac)
# Out:
# [[74  5]
#  [ 4 37]]
# 0.925

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# sklearn.cluster.KMeans(n_clusters=k)
#
# Fine tuning:
# 1. change k in such a way to balance overfit and underfit model and without any ambiguity
# 2. choose right features - age/culture
#
# Applications:
# recommender systems
# business forecasting

# %% [markdown]
# regression - supervised
# classification - supervised
# clustering - unsupervised - no label, find insights, cant find accuracy
# reinforcement learning - environment, actor, actions
# reward and punishment
# markov model - present state depends only on previous state
# eg: self-driving cars, autonomous vehicles, UAV drones
#
# bias
# variance
# regularization
# fine tuning
#
# linear regression
# logistic regression
# decision tree
# random forest
# support vector machine
# k nearest neighbor
# k means
